# %% [markdown]
# Multilinear Regression project with python

# %% [markdown]
# To illustrate multiple linear regression we are using the Mobile price prediction dataset to predict cellphone price from it's features

# %%
pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn
# Out:
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
# ...

# %%
pip install sklearn
# Out:
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
# ...

# %%
import pandas as pd

df =pd.read_csv('Cellphone.csv')
df.head()
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
df.shape
# Out:
# (161, 14)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_id    161 non-null    int64
#  1   Price         161 non-null    int64
#  2   Sale          161 non-null    int64
#  3   weight        161 non-null    float64
#  4   resoloution   161 non-null    float64
#  5   ppi           161 non-null    int64
#  6   cpu core      161 non-null    int64
#  7   cpu freq      161 non-null    float64
#  8   internal mem  161 non-null    float64
#  9   ram           161 non-null    float64
#  10  RearCam       161 non-null    float64
#  11  Front_Cam     161 non-null    float64
#  12  battery       161 non-null    int64
#  13  thickness     161 non-null    float64
# dtypes: float64(8), int64(6)
# memory usage: 17.7 KB

# %%
df.describe()
# Out:
#         Product_id        Price         Sale      weight  resoloution  \
# count   161.000000   161.000000   161.000000  161.000000   161.000000
# mean    675.559006  2215.596273   621.465839  170.426087     5.209938
# std     410.851583   768.187171  1546.618517   92.888612     1.509953
# min      10.000000   614.000000    10.000000   66.000000     1.400000
# 25%     237.000000  1734.000000    37.000000  134.100000     4.800000
# 50%     774.000000  2258.000000   106.000000  153.000000     5.150000
# 75%    1026.000000  2744.000000   382.000000  170.000000     5.500000
# max    1339.000000  4361.000000  9807.000000  753.000000    12.200000
#
#               ppi    cpu core    cpu freq  internal mem         ram  \
# count  161.000000  161.000000  161.000000    161.000000  161.000000
# mean   335.055901    4.857143    1.502832     24.501714    2.204994
# std    134.826659    2.444016    0.599783     28.804773    1.609831
# ...

# %%
df.isnull().sum()
# Out:
# Product_id      0
# Price           0
# Sale            0
# weight          0
# resoloution     0
# ppi             0
# cpu core        0
# cpu freq        0
# internal mem    0
# ram             0
# RearCam         0
# Front_Cam       0
# battery         0
# thickness       0
# dtype: int64

# %%
## To check if the input features are collinear we use a correllation heatmap

# %%
df.select_dtypes(include=['number']).corr()
# Out:
#               Product_id     Price      Sale    weight  resoloution       ppi  \
# Product_id      1.000000  0.165136  0.218548  0.035869    -0.017817  0.207271
# Price           0.165136  1.000000  0.273263  0.144555     0.404010  0.817614
# Sale            0.218548  0.273263  1.000000  0.016114     0.017154  0.235896
# weight          0.035869  0.144555  0.016114  1.000000     0.890416 -0.054683
# resoloution    -0.017817  0.404010  0.017154  0.890416     1.000000  0.181292
# ppi             0.207271  0.817614  0.235896 -0.054683     0.181292  1.000000
# cpu core       -0.008634  0.686811  0.069517  0.216257     0.472226  0.487990
# cpu freq        0.092428  0.727383  0.099133  0.222730     0.505454  0.713168
# internal mem    0.261186  0.776738  0.489308  0.098849     0.202660  0.618560
# ram             0.236194  0.896915  0.373127  0.149283     0.327216  0.748724
# RearCam         0.172812  0.739538  0.292164 -0.029448     0.249892  0.774008
# ...

# %% [markdown]
# To see if some of the features are strongly correlates with each other

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(18,8))
corr_df = df.select_dtypes(include=['number']).corr()
sns.heatmap(corr_df, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %% [markdown]
# To get an understanding of the relationship between input features and price (output feature) in a scatter plot

# %%
plt.scatter(df['ppi'],df['Price'],color='blue')
plt.xlabel('ppi')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# To get an understanding of the relationship between input (cpu freq) features and price (output feature) in a scatter plot

# %%
plt.scatter(df['cpu freq'],df['Price'], color='blue')
plt.xlabel('cpu freq')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# To get an understanding of the relationship between input (cpu core) features and price (output feature) in a scatter plot

# %%
plt.scatter(df['cpu core'],df['Price'], color='blue')
plt.xlabel('Price')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# To get an understanding of the relationship between input (thickness) features and price (output feature) in a scatter plot

# %%
plt.scatter(df['thickness'],df['Price'],color='blue')
plt.xlabel('Thickness')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# There seem to be no linearity between thickness variable and our linear regression model

# %% [markdown]
# ### Now the next step in training a model is to split the data between training and testing

# %% [markdown]
# ## 80% training data
# ## 20% testing data

# %%
import numpy as np
msk = np.random.rand(len(df)) < 0.8
training = df[msk]
test = df[~msk]

# %% [markdown]
# we fit the regr model to "(X_train,y_train)"

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()

train_x = np.asanyarray(training[['ppi','cpu freq','cpu core','ram','RearCam','Front_Cam','battery']])
train_y = np.asanyarray(training['Price'])
regr.fit(train_x,train_y)

print('y intercept',regr.intercept_)
print('Coefficient',regr.coef_)
# Out:
# y intercept 581.3942404769136
# Coefficient [ 1.43549584e+00  1.14069831e+02  7.37324660e+01  2.14797326e+02
#  -8.56628574e-01  1.33857592e+01  3.40060257e-02]

# %% [markdown]
# Now we apply the trained "regr" model to "x_test" to predict values of "y_test"

# %%
text_test_x = np.asanyarray(test[['ppi','cpu freq','cpu core','ram','RearCam','Front_Cam','battery']])
test_y = np.asanyarray(test['Price'])
test_y_ = regr.predict(text_test_x)

# %%
from sklearn.metrics import r2_score
print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_ - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_ - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y_ , test_y) )
# Out:
# Mean absolute error: 141.44
# Residual sum of squares (MSE): 34275.52
# R2-score: 0.95
